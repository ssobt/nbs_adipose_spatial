# %%
## Notebook env: cell2loc_env (cell2loc_env kernel)
## this notebook performs cell2location to *spatially* deconvolute cells using a reference annotated scRNAseq dataset

# %%
import sys
import scanpy as sc
import anndata
import pandas as pd
import numpy as np
import os

data_type = 'float32'

import cell2location

import matplotlib as mpl
from matplotlib import rcParams
import matplotlib.pyplot as plt
import seaborn as sns

# silence scanpy that prints a lot of warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# Global seed set to 0

# %%
results_folder = '/home/ssobti/projects/farnaz_spatial/output_data/cell2location/multi_ref_annot'

# create paths and names to results folders for reference regression and cell2location models
ref_run_name = f'{results_folder}/reference_signatures'
run_name = f'{results_folder}/cell2location_map/N2_alpha20'

# %%
adata_file = f"{run_name}/sp.h5ad"
adata_vis = sc.read_h5ad(adata_file)
mod = cell2location.models.Cell2location.load(f"{run_name}", adata_vis)
# Out:
# INFO     File
#          /home/ssobti/projects/farnaz_spatial/output_data/cell2location/multi_ref_annot/cell2location_map/N2_alpha2
#          0/model.pt already downloaded
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Epoch 1/30000:   0%|                                   | 1/30000 [00:04<37:07:22,  4.45s/it, v_num=1, elbo_train=1.48e+8]
# `Trainer.fit` stopped: `max_steps=1` reached.
# Epoch 1/30000:   0%|                                   | 1/30000 [00:04<37:11:28,  4.46s/it, v_num=1, elbo_train=1.48e+8]

# %%
adata_vis.obsm['spatial']
# Out:
# array([[1393, 1193],
#        [ 454, 1376],
#        [ 339, 1062],
#        ...,
#        [ 751, 1451],
#        [ 580, 1196],
#        [ 847,  446]])

# %%
adata_vis.obsm['q05_cell_abundance_w_sf']
# Out:
#                              q05cell_abundance_w_sf_Adipocyte_progenitors  \
# spot_id
# count-A1_AAACAAGTATCTCCCA-1                                      0.262522
# count-A1_AAACACCAATAACTGC-1                                      0.006819
# count-A1_AAACAGCTTTCAGAAG-1                                      0.013219
# count-A1_AAACAGGGTCTATATT-1                                      0.018923
# count-A1_AAACAGTGTTCCTGGG-1                                      0.006787
# ...                                                                   ...
# count-D1_TTGTTAGCAAATTCGA-1                                      0.019799
# count-D1_TTGTTCAGTGTGCTAC-1                                      0.040310
# count-D1_TTGTTTCACATCCAGG-1                                      0.016693
# count-D1_TTGTTTCCATACAACT-1                                      0.015628
# count-D1_TTGTTTGTGTAAATTC-1                                      0.016167
#
#                              q05cell_abundance_w_sf_Adipocytes  \
# spot_id
# count-A1_AAACAAGTATCTCCCA-1                           0.042641
# count-A1_AAACACCAATAACTGC-1                           0.078485
# count-A1_AAACAGCTTTCAGAAG-1                           0.049115
# count-A1_AAACAGGGTCTATATT-1                           0.072705
# count-A1_AAACAGTGTTCCTGGG-1                           0.104081
# ...                                                        ...
# count-D1_TTGTTAGCAAATTCGA-1                           0.067285
# count-D1_TTGTTCAGTGTGCTAC-1                           0.084798
# count-D1_TTGTTTCACATCCAGG-1                           0.021247
# count-D1_TTGTTTCCATACAACT-1                           0.058105
# count-D1_TTGTTTGTGTAAATTC-1                           0.104233
#
#                              q05cell_abundance_w_sf_B_cells  \
# spot_id
# count-A1_AAACAAGTATCTCCCA-1
\
# spot_id
# count-A1_AAACAAGTATCTCCCA-1                      0.024805
# count-A1_AAACACCAATAACTGC-1                      0.037644
# count-A1_AAACAGCTTTCAGAAG-1                      0.016832
# count-A1_AAACAGGGTCTATATT-1                      0.022124
# count-A1_AAACAGTGTTCCTGGG-1                      0.012993
# ...                                                   ...
# count-D1_TTGTTAGCAAATTCGA-1                      0.018072
# count-D1_TTGTTCAGTGTGCTAC-1                      0.037294
# count-D1_TTGTTTCACATCCAGG-1                      0.013390
# count-D1_TTGTTTCCATACAACT-1                      0.016204
# count-D1_TTGTTTGTGTAAATTC-1                      0.015385
#
#                              q05cell_abundance_w_sf_Vascular_smooth_muscle  \
# spot_id
# count-A1_AAACAAGTATCTCCCA-1                                       0.073843
# count-A1_AAACACCAATAACTGC-1                                       0.043592
# count-A1_AAACAGCTTTCAGAAG-1                                       0.027270
# count-A1_AAACAGGGTCTATATT-1                                       0.034211
# count-A1_AAACAGTGTTCCTGGG-1                                       0.070737
# ...                                                                    ...
# count-D1_TTGTTAGCAAATTCGA-1                                       0.062498
# count-D1_TTGTTCAGTGTGCTAC-1                                       0.026323
# count-D1_TTGTTTCACATCCAGG-1                                       0.021311
# count-D1_TTGTTTCCATACAACT-1                                       0.048898
# count-D1_TTGTTTGTGTAAATTC-1                                       0.042030
#
#                              q05cell_abundance_w_sf_white adipocytes
# spot_id
# count-A1_AAACAAGTATCTCCCA-1                                 0.042457
# count-A1_AAACACCAATAACTGC-1                                 0.052426
# count-A1_AAACAGCTTTCAGAAG-1                                 0.044347
# count-A1_AAACAGGGTCTATATT-1                                 0.052015
# count-A1_AAACAGTGTTCCTGGG-1                                 0.057099
# ...                                                              ...
# count-D1_TTGTTAGCAAATTCGA-1                                 0.045963
# count-D1_TTGTTCAGTGTGCTAC-1                                 0.040674
# count-D1_TTGTTTCACATCCAGG-1                                 0.021579
# count-D1_TTGTTTCCATACAACT-1                                 0.039876
# count-D1_TTGTTTGTGTAAATTC-1                                 0.061665
#
# [10486 rows x 20 columns]

# %%
adata_vis.uns['mod']['factor_names']
# Out:
# array(['Adipocyte_progenitors', 'Adipocytes', 'B_cells',
#        'Brown_adipocytes', 'Endothelial_cells', 'Eosinophils',
#        'Epithelial_cells', 'Lymphatic_endothelial_cells', 'Macrophages',
#        'Mast_cells', 'Mesothelium', 'NK_cells', 'Neutrophils',
#        'Pericytes', 'Schwan_cells', 'Skeletal_muscle', 'T_cells', 'Tregs',
#        'Vascular_smooth_muscle', 'white adipocytes'], dtype=object)

# %%
# add 5% quantile, representing confident cell abundance, 'at least this amount is present',
# to adata.obs with nice names for plotting
adata_vis.obs[adata_vis.uns['mod']['factor_names']] = adata_vis.obsm['q05_cell_abundance_w_sf']

# select one slide
from cell2location.utils import select_slide
slide = select_slide(adata_vis, 'count-D1') ## slide name to select here

# plot in spatial coordinates
with mpl.rc_context({'axes.facecolor':  'black',
                     'figure.figsize': [4.5, 5]}):

    sc.pl.spatial(slide, cmap='magma',
                  # show first 8 cell types
                  color=list(adata_vis.uns['mod']['factor_names']),
                  ncols=4, size=1.3,
                  img_key='hires',
                  # limit color scale at 99.2% quantile of cell abundance
                  vmin=0, vmax='p99.2', show = False
                 )
    plt.savefig('/home/ssobti/projects/farnaz_spatial/output_data/cell2location/multi_ref_annot/other_outputs/N2_alpha20_D1.pdf', bbox_inches="tight")

# %%
# compute KNN using the cell2location output stored in adata.obsm
sc.pp.neighbors(adata_vis, use_rep='q05_cell_abundance_w_sf',
                n_neighbors = 15)

# Cluster spots into regions using scanpy
sc.tl.leiden(adata_vis, resolution=1.1)

# add region as categorical variable
adata_vis.obs["region_cluster"] = adata_vis.obs["leiden"].astype("category")

# %%
# compute UMAP using KNN graph based on the cell2location output
sc.tl.umap(adata_vis, min_dist = 0.3, spread = 1)

# show regions in UMAP coordinates
with mpl.rc_context({'axes.facecolor':  'white',
                     'figure.figsize': [8, 8]}):
    sc.pl.umap(adata_vis, color=['region_cluster'], size=30,
               color_map = 'RdPu', ncols = 2, legend_loc='on data',
               legend_fontsize=20)
    sc.pl.umap(adata_vis, color=['sample'], size=30,
               color_map = 'RdPu', ncols = 2,
               legend_fontsize=20)

# %%
# plot in spatial coordinates
with mpl.rc_context({'axes.facecolor':  'black',
                     'figure.figsize': [4.5, 5]}):
    sc.pl.spatial(adata_vis, color=['region_cluster'],
                  size=1.3, img_key='hires', alpha=0.5, library_id='count-A1')
    sc.pl.spatial(adata_vis, color=['region_cluster'],
                  size=1.3, img_key='hires', alpha=0.5, library_id='count-B1')
    sc.pl.spatial(adata_vis, color=['region_cluster'],
                  size=1.3, img_key='hires', alpha=0.5, library_id='count-C1')
    sc.pl.spatial(adata_vis, color=['region_cluster'],
                  size=1.3, img_key='hires', alpha=0.5, library_id='count-D1')

# %% [markdown]
# ## NMF

# %%
from cell2location import run_colocation
res_dict, slide = run_colocation(
    adata_vis,
    model_name='CoLocatedGroupsSklearnNMF',
    train_args={
      'n_fact': np.arange(5, 30), # IMPORTANT: use a wider range of the number of factors (5-30)
      'sample_name_col': 'sample', # columns in adata_vis.obs that identifies sample
      'n_restarts': 3 # number of training restarts
    },
    # the hyperparameters of NMF can be also adjusted:
    model_kwargs={'alpha': 0.01, 'init': 'random', "nmf_kwd_args": {"tol": 0.000001}},
    export_args={'path': f'{run_name}/CoLocatedComb/'}
)
# Out:
# ### Analysis name: CoLocatedGroupsSklearnNMF_5combinations_10486locations_16factors
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 2
#       1 from cell2location import run_colocation
# ----> 2 res_dict, slide = run_colocation(
#       3     adata_vis,
#       4     model_name='CoLocatedGroupsSklearnNMF',
#       5     train_args={
#       6       'n_fact': np.arange(5, 30), # IMPORTANT: use a wider range of the number of factors (5-30)
#       7       'sample_name_col': 'sample', # columns in adata_vis.obs that identifies sample
#       8       'n_restarts': 3 # number of training restarts
#       9     },
#      10     # the hyperparameters of NMF can be also adjusted:
#      11     model_kwargs={'alpha': 0.01, 'init': 'random', "nmf_kwd_args": {"tol": 0.000001}},
#      12     export_args={'path': f'{run_name}/CoLocatedComb/'}
#      13 )
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.10/site-packages/cell2location/run_colocation.py:350, in run_colocation(sp_data, n_neighbours, model_name, verbose, return_all, train_args, model_kwargs, posterior_args, export_args)
#     348     mkdir(fig_path)
#     349 # plot co-occuring cell type combinations
# --> 350 mod.plot_cell_type_loadings(
#     351     **export_args["plot_cell_type_loadings_kwargs"],
#     352 )
#     354 save_plot(fig_path, filename=f"n_fact{mod.n_fact}", extension=export_args["plot_extension"])
#     355 if verbose:
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.10/site-packages/cell2location/models/downstream/CoLocatedGroupsSklearnNMF.py:240, in CoLocatedGroupsSklearnNMF.plot_cell_type_loadings(self, selected_cell_types, **kwargs)
#     237 if selected_cell_types is None:
#     238     selected_cell_types = self.var_names_read
# --> 240 self.plot_gene_loadings(
#     241     sel_var_names=selected_cell_types,
#     242     var_names=self.var_names_read,
#     243     fact_filt=self.fact_filt,
#     244     loadings_attr="cell_type_fractions",
#     245     gene_fact_name="cell_type_fractions",
#     246     fun_type="dotplot",
#     247     cmap="RdPu",
#     248     figsize=[5 + 0.12 * self.n_fact, 5 + 0.1 * self.n_var],
#     249     **kwargs
#     250 )
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.10/site-packages/cell2location/models/base/base_model.py:396, in BaseModel.plot_gene_loadings(self, sel_var_names, var_names, gene_fact_name, loadings_attr, figsize, cluster_factors, cluster_genes, cmap, title, fact_filt, fun_type, return_linkage)
#     393 key_markers.index = self.var_names_read[sel_index]  # use readable names
#     394 key_markers = key_markers.loc[sel_var_names, :]  # reorder
# --> 396 clustermap(
#     397     key_markers,
#     398     cluster_rows=cluster_genes,
#     399     cluster_cols=cluster_factors,
#     400     return_linkage=return_linkage,
#     401     figure_size=figsize,
#     402     cmap=cmap,
#     403     title=title,
#     404     fun_type=fun_type,
#     405 )
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.10/site-packages/cell2location/plt/plot_heatmap.py:187, in clustermap(df, cluster_rows, cluster_cols, figure_size, cmap, log, return_linkage, equal, title, fun_type, array_size, vmin, vmax)
#     184 if cluster_rows:
#     185     # hierarchically cluster rows
#     186     cor_f1 = np.corrcoef(df)
# --> 187     row_linkage = hierarchy.linkage(distance.pdist(cor_f1), method="average")
#     188     row_ord = hierarchy.leaves_list(row_linkage)
#     189 else:
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.10/site-packages/scipy/cluster/hierarchy.py:1065, in linkage(y, method, metric, optimal_ordering)
#    1062     raise ValueError("`y` must be 1 or 2 dimensional.")
#    1064 if not np.all(np.isfinite(y)):
# -> 1065     raise ValueError("The condensed distance matrix must contain only "
#    1066                      "finite values.")
#    1068 n = int(distance.num_obs_y(y))
#    1069 method_code = _LINKAGE_METHODS[method]
#
# ValueError: The condensed distance matrix must contain only finite values.

# %%
# Compute expected expression per cell type
expected_dict = mod.module.model.compute_expected_per_cell_type(
    mod.samples["post_sample_q05"], mod.adata_manager
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 3
#       1 # Compute expected expression per cell type
#       2 expected_dict = mod.module.model.compute_expected_per_cell_type(
# ----> 3     mod.samples["post_sample_q05"], mod.adata_manager
#       4 )
#
# AttributeError: 'Cell2location' object has no attribute 'samples'

# %%
mod.print_gene_loadings(
            loadings_attr="cell_type_fractions",
            gene_fact_name="cell_type_fractions",
            top_n=min(export_args["top_n"], len(var_names)),
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 mod.print_gene_loadings(
#       2             loadings_attr="cell_type_fractions",
#       3             gene_fact_name="cell_type_fractions",
#       4             top_n=min(export_args["top_n"], len(var_names)),
#       5         )
#
# NameError: name 'mod' is not defined

# %%
mod.print_gene_loadings(gene_fact_name="gene_factors", loadings_attr="gene_loadings", top_n=10, gene_filt=None, fact_filt=None)

# %%
del mod

# %%
slide.gene_loadings
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 slide.gene_loadings
#
# AttributeError: 'AnnData' object has no attribute 'gene_loadings'

# %%
for key in slide.obsm['q05_cell_abundance_w_sf'].keys():
    print(len(slide.obsm['q05_cell_abundance_w_sf'][key]))
# Out:
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733

# %%
for key in slide.obsm['q05_cell_abundance_w_sf'].keys():
    print(len(np.where(np.isfinite(slide.obsm['q05_cell_abundance_w_sf'][key]))[0]))
# Out:
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733
# 2733

# %%
slide.obsm['q05_cell_abundance_w_sf'].shape
# Out:
# (2733, 16)

# %%
for x in slide.obsm['q05_cell_abundance_w_sf']['q05cell_abundance_w_sf_ASPC']:
    print(x)
# Out:
# 0.30738964676856995
# 0.00722815147601068
# 0.02148762345314026
# 0.02193636205047369
# 0.007811892731115222
# 0.025185628421604635
# 0.15726989954710008
# 0.00610615632031113
# 0.015974231529980898
# 0.011918534385040402
# 0.00985415568575263
# 0.010011009266600012
# 0.045146756991744044
# 0.006436661840416491
# 0.023785592056810856
# 0.010414586355909704
# 0.13098113387823104
# 0.008478251053020358
# 0.006372372363694012
# 0.018700926657766105
# 0.05220769289880991
# 0.0311010398901999
# 0.00953899985179305
# 0.007513625849969685
# 0.006407392141409218
# 0.17019299045205116
# 0.018771461956202985
# 0.015064776223152877
# 0.050801531225442884
# 0.015569324325770139
# 0.78510881960392
# 0.010694215632975101
# 0.009858583146706224
# 0.01010147393681109
# 0.012026856560260058
# 0.06740889251232147
# 0.009145605424419046
# 0.4609802633523941
# 0.04428563769906759
# 0.043825313262641434
# 0.02465785751119256
# 0.027091300673782827
# 0.018684824276715518
# 0.01602042717859149
# 0.056767648085951805
# 0.006141552841290832
# 0.0350544111803174
# 0.043587098643183705
# 0.008642839873209596
# 0.008539948426187039
# 0.030411403626203537
# 0.016923690680414438
# 0.009259001631289721
# 0.00824740850366652
# 0.017766150273382665
# 0.007035380019806326
# 0.010769705194979906
# 0.11014321893453598
# 0.021409126464277506
# 0.07279258891940117
# 0.015031794039532542
# 0.013341122074052691
# 0.0310700842179358
# 0.006087844655849039
# 0.03042809125036001
# 0.6036609828472137
# 0.013868979923427106
# 0.022424949053674936
# 0.025513261463493107
# 0.00928279054351151
# 0.009109180886298418
# 0.011964837834239007
# 0.029730029031634332
# 0.07659174427390099
# 0.01071956530213356
# 0.028451017010957
# 0.01365141775459051
# 0.008659793715924024
# 0.014930520672351122
# 0.015213841060176493
# 0.008313547680154442
# 0.015829921513795853
# 0.010391454584896565
# 0.010373924067243934
# 0.01041868762113154
# 0.007906723767518997
# 0.011686555249616504
# 0.013596969190984964
# 0.010964286420494318
# 0.012677410058677197
# 0.13812192156910896
# 0.030570547841489316
# 0.007471458078362048
# 0.007299206615425646
# 0.03804011829197407
# 0.00996553455479443
# 0.01364181712269783
# 0.025927663128823043
# 0.03445909731090069
# 0.005609284527599812
# 0.036026747711002824
# 0.02008266290649772
# 0.018370045814663172
# 0.014553304202854634
# 0.008698530308902264
# 0.00718071183655411
# 0.0075666845543310044
# 0.06162674482911825
# 0.021439968049526213
# 0.023672920372337102
# 0.04366594944149256
# 0.010853245016187429
# 0.015089003602042794
# 0.011872371472418309
# 0.024489900190383197
# 0.020349064376205206
# 0.011018542246893049
# 0.010298456205055118
# 0.00859045614488423
# 0.00915018953382969
# 0.010347905661910772
# 0.01698676720261574
# 0.015151166124269366
# 0.008324063895270229
# 0.00758848674595356
# 0.09041511677205563

# %%
mod = Model(
    10,
    slide.obsm['q05_cell_abundance_w_sf'],
    n_iter=20000,
    verbose=verbose,
    var_names=list(slide.uns["mod"]['factor_names']) + ["neigh_" + i for i in slide.uns["mod"]['factor_names']],
    obs_names=slide.obs_names,
    fact_names=["fact_" + str(i) for i in range(30)],
    sample_id=slide.obs['sample'],
    **model_kwargs,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 mod = Model(
#       2     10,
#       3     slide.obsm['q05_cell_abundance_w_sf'],
#       4     n_iter=20000,
#       5     verbose=verbose,
#       6     var_names=list(slide.uns["mod"]['factor_names']) + ["neigh_" + i for i in slide.uns["mod"]['factor_names']],
#       7     obs_names=slide.obs_names,
#       8     fact_names=["fact_" + str(i) for i in range(30)],
#       9     sample_id=slide.obs['sample'],
#      10     **model_kwargs,
#      11 )
#
# NameError: name 'Model' is not defined

# %%
d_model_kwargs = {"init": "random", "random_state": 0, "nmf_kwd_args": {"tol": 0.000001}, "alpha": 0.01}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 slide.obs[train_args["sample_name_col"]]
#
# NameError: name 'train_args' is not defined

# %%
# create model class
n_fact = int(n_fact)
mod = Model(
    n_fact,
    X_data,
    n_iter=train_args["n_iter"],
    verbose=verbose,
    var_names=var_names,
    obs_names=obs_names,
    fact_names=["fact_" + str(i) for i in range(n_fact)],
    sample_id=sample_id,
    **model_kwargs,
)

####### Print run name #######
run_name = (
    str(mod.__class__.__name__)
    + "_"
    + str(mod.n_fact)
    + "combinations_"
    + str(mod.n_obs)
    + "locations_"
    + str(mod.n_var)
    + "factors"
    + export_args["run_name_suffix"]
)
path_name = (
    str(mod.__class__.__name__)
    + "_"
    + str(mod.n_obs)
    + "locations_"
    + str(mod.n_var)
    + "factors"
    + export_args["run_name_suffix"]
)

# %%
tt[0].sum()
# Out:
# 59732448

# %%
np.where([True, False,ddTrue])
# Out:
# (array([0, 2]),)
