# %%
library(dplyr)
library(patchwork)
library(Seurat)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching SeuratObject

# %%
human_all <- readRDS("/home/ssobti/projects/farnaz_spatial/data/human_all.rds")

# %%
tt <- rownames(human_all)

# %%
grep('Hb.*', tt)
# Out:
# integer(0)

# %%
tt[1]
# Out:
# [1] "A1BG"

# %%
class(human_all)
# Out:
# [1] "Seurat"
# attr(,"package")
# [1] "SeuratObject"

# %%
DimPlot(human_all)
# Out:
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`
# plot without title

# %%
class(tt)
# Out:
# [1] "list"

# %%
mouse_all <- readRDS("/home/ssobti/projects/farnaz_spatial/data/mouse_all_sct.rds")

mBAT <- readRDS("/home/ssobti/projects/farnaz_spatial/data/seurat_mBAT.rds")
